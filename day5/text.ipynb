# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("C:\sam\day5\mark.csv")
print(df.head())
# Out:
#    Marks  Hours
# 0     45      3
# 1     67      5
# 2     72      4
# 3     55      6
# 4     89      2
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\User\AppData\Local\Temp\ipykernel_15000\4241892909.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv("C:\sam\day5\mark.csv")

# %%
#prepare the data
x = df.loc[:,['Hours']].values 
y = df.loc[:,'Marks'].values



x_train, x_test, y_train, y_test= train_test_split(
    x,y,test_size=0.2,random_state=42
)
print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
regressor = LinearRegression()
regressor.fit(x_train,y_train)

print("Training complete.")
# Out:
# Training complete.

# %%
y_pred = regressor.predict(x_test)
print("prediction compleated")

mse = mean_squared_error(y_test , y_pred)
r2 = r2_score(y_test, y_pred)
print(f"mean squared error :- {mse}")
print(f"r^2 score :- {r2:2f}")
# Out:
# prediction compleated
# mean squared error :- 217.31405464193094
# r^2 score :- 0.227938

# %%
line = regressor.coef_ * x + regressor.intercept_

plt .figure(figsize=(10,6))
plt.scatter(x,y,color = "cyan",s=100,label = "data points")
plt.plot(x,line,color = "crimson",label = "regression line")
plt.xlabel("Hours Studied")
plt.ylabel("percentage scored")
plt.title("Hours vs Scores")
plt.legend()
plt.show()

# %%
hours = float(input("enter hours"))
prediction = regressor.predict([[hours]])
print(f"Predicted score for {hours} hours of study : {prediction[0]:.2f}")
# Out:
# Predicted score for 2.0 hours of study : 77.73
